# %% [markdown]
# # Exploring Fastf1 Library

# %%
pip install fastf1
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ...

# %%
import fastf1
from fastf1 import plotting
from fastf1.ergast import Ergast
import matplotlib.pyplot as plt

import os
os.makedirs('cache', exist_ok=True)  # Creates the folder if it doesn't exist

import fastf1
fastf1.Cache.enable_cache('cache')   # Now it won't error

# Enable cache to avoid redownloading data
fastf1.Cache.enable_cache('cache')  # Creates a "cache" folder locally

# Load session: Race from 2023 Italian Grand Prix
session = fastf1.get_session(2023, 'Monza', 'R')  # 'R' for Race
session.load()

# Check what data is available
print(session.results.head())  # Basic race results (positions, drivers, teams)
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
print(session.results.tail())
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId      TeamName  \
# 18           18      L STROLL          STR           stroll  Aston Martin
# 27           27  N HULKENBERG          HUL       hulkenberg  Haas F1 Team
# 20           20   K MAGNUSSEN          MAG  kevin_magnussen  Haas F1 Team
# 31           31        E OCON          OCO             ocon        Alpine
# 22           22     Y TSUNODA          TSU          tsunoda    AlphaTauri
#
#    TeamColor        TeamId FirstName    LastName         FullName  ...  \
# 18    358C75  aston_martin     Lance      Stroll     Lance Stroll  ...
# 27    B6BABD          haas      Nico  Hulkenberg  Nico Hulkenberg  ...
# 20    B6BABD          haas     Kevin   Magnussen  Kevin Magnussen  ...
# 31    2293D1        alpine   Esteban        Ocon     Esteban Ocon  ...
# 22    5E8FAA    alphatauri      Yuki     Tsunoda     Yuki Tsunoda  ...
#
#    Position ClassifiedPosition  GridPosition  Q1  Q2  Q3  \
# ...

# %%
session_csv_df = session.results

# %%
session_csv_df.to_csv(r"D:\Masters Study Abroad\Self Study\Personal Projects\F1\F1_test_data.csv")

# %%
# Load Free Practice 1
fp1 = fastf1.get_session(2023, 'Silverstone', 'FP1')
fp1.load()

# Load Qualifying
qualifying = fastf1.get_session(2023, 'Monaco', 'Q')
qualifying.load()

# Load the Race
race = fastf1.get_session(2023, 'Spa', 'R')
race.load()
# Out:
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
print(fp1.results.head())
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 2             2    L SARGEANT          SAR        sargeant         Williams
# 4             4      L NORRIS          NOR          norris          McLaren
# 10           10       P GASLY          GAS           gasly           Alpine
# 11           11       S PEREZ          PER           perez  Red Bull Racing
#
#    TeamColor    TeamId FirstName    LastName        FullName  ... Position  \
# 1     3671C6  red_bull       Max  Verstappen  Max Verstappen  ...      NaN
# 2     37BEDD  williams     Logan    Sargeant  Logan Sargeant  ...      NaN
# 4     F58020   mclaren     Lando      Norris    Lando Norris  ...      NaN
# 10    2293D1    alpine    Pierre       Gasly    Pierre Gasly  ...      NaN
# 11    3671C6  red_bull    Sergio       Perez    Sergio Perez  ...      NaN
#
# ...

# %%
print(qualifying.results.head())
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 31           31        E OCON          OCO            ocon           Alpine
# 55           55       C SAINZ          SAI           sainz          Ferrari
#
#    TeamColor        TeamId FirstName    LastName         FullName  ...  \
# 1     3671C6      red_bull       Max  Verstappen   Max Verstappen  ...
# 14    358C75  aston_martin  Fernando      Alonso  Fernando Alonso  ...
# 16    F91536       ferrari   Charles     Leclerc  Charles Leclerc  ...
# 31    2293D1        alpine   Esteban        Ocon     Esteban Ocon  ...
# 55    F91536       ferrari    Carlos       Sainz     Carlos Sainz  ...
#
#    Position ClassifiedPosition  GridPosition                     Q1  \
# ...

# %%
print(qualifying.laps.head())
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:15:52.796000    VER            1 0 days 00:01:49.496000
# 1 0 days 00:17:06.580000    VER            1 0 days 00:01:13.784000
# 2 0 days 00:19:08.545000    VER            1 0 days 00:02:01.965000
# 3 0 days 00:30:13.467000    VER            1                    NaT
# 4 0 days 00:31:53.102000    VER            1 0 days 00:01:39.635000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0 0 days 00:14:05.753000                    NaT
# 1        2.0    1.0                    NaT                    NaT
# 2        3.0    1.0                    NaT                    NaT
# 3        4.0    1.0                    NaT 0 days 00:20:42.905000
# 4        5.0    2.0 0 days 00:30:14.555000                    NaT
#
#              Sector1Time            Sector2Time  ... FreshTyre  \
# 0 0 days 00:00:40.759000 0 days 00:00:43.892000  ...      True
# ...

# %%
qualifying_laps_test_df = qualifying.laps

# %%
qualifying_laps_test_df.to_csv(r"D:\Masters Study Abroad\Self Study\Personal Projects\F1\F1_test_data_02.csv")

# %%
print(session.laps.head())
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:23:49.780000    VER            1 0 days 00:01:27.905000
# 1 0 days 01:25:15.943000    VER            1 0 days 00:01:26.163000
# 2 0 days 01:26:41.645000    VER            1 0 days 00:01:25.702000
# 3 0 days 01:28:07.695000    VER            1 0 days 00:01:26.050000
# 4 0 days 01:29:33.871000    VER            1 0 days 00:01:26.176000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:28.274000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:28.097000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:28.145000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:28.155000
#
#              Sector2Time  ... FreshTyre             Team  \
# 0 0 days 00:00:29.666000  ...      True  Red Bull Racing
# ...

# %%
session_laps_test_df = session.laps
session_laps_test_df.to_csv(r"D:\Masters Study Abroad\Self Study\Personal Projects\F1\F1_test_data_03.csv")

# %%
print(session.weather_data.head())
# Out:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:36.015000     28.5      45.0    1001.0     False       43.2
# 1 0 days 00:01:36.014000     28.6      45.0    1001.2     False       43.3
# 2 0 days 00:02:36.014000     28.5      45.0    1001.0     False       43.3
# 3 0 days 00:03:36.013000     28.5      45.0    1001.0     False       43.3
# 4 0 days 00:04:36.012000     28.4      46.0    1001.0     False       42.8
#
#    WindDirection  WindSpeed
# 0            302        1.8
# 1            287        2.0
# 2            269        0.6
# 3            154        0.8
# 4            274        0.8

# %%
session_weather_test_df = session.weather_data
session_weather_test_df.to_csv(r"D:\Masters Study Abroad\Self Study\Personal Projects\F1\F1_test_data_04.csv")

# %%
print(session.get_driver('VER').head())
# Out:
# DriverNumber                   1
# BroadcastName       M VERSTAPPEN
# Abbreviation                 VER
# DriverId          max_verstappen
# TeamName         Red Bull Racing
# Name: 1, dtype: object

# %%
print(session.get_driver('VER').tail())
# Out:
# Q3                           NaT
# Time      0 days 01:13:41.143000
# Status                  Finished
# Points                      25.0
# Laps                        51.0
# Name: 1, dtype: object

# %%
session_driver_test_df = session.get_driver('VER')
session_driver_test_df.to_csv(r"D:\Masters Study Abroad\Self Study\Personal Projects\F1\F1_test_data_05.csv")

# %%
laps = session.laps.pick_drivers('VER')  # All laps by Max
fastest_lap = laps.pick_fastest()      # Get his fastest lap
telemetry = fastest_lap.get_car_data() # Get telemetry for that lap

print(telemetry.head())  # Show the first few rows
# Out:
#                      Date      RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0 2023-09-03 14:09:46.548  11087.0  311.0      8     100.0  False    0    car
# 1 2023-09-03 14:09:46.908  11154.0  314.0      8     100.0  False    0    car
# 2 2023-09-03 14:09:47.108  11169.0  315.0      8     100.0  False    0    car
# 3 2023-09-03 14:09:47.268  11230.0  316.0      8     100.0  False    0    car
# 4 2023-09-03 14:09:47.628  11270.0  319.0      8     100.0  False    0    car
#
#                     Time            SessionTime
# 0 0 days 00:00:00.210000 0 days 02:08:45.503000
# 1 0 days 00:00:00.570000 0 days 02:08:45.863000
# 2 0 days 00:00:00.770000 0 days 02:08:46.063000
# 3 0 days 00:00:00.930000 0 days 02:08:46.223000
# 4 0 days 00:00:01.290000 0 days 02:08:46.583000

# %%
telemetry_df = telemetry

# %%
telemetry_df.to_csv(r"D:\Masters Study Abroad\Self Study\Personal Projects\F1\F1_test_data_06.csv")
